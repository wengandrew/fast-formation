# %% [markdown]
# # Sanity check confounding variable
#
# Objective: make sure that the correlations we are seeing isn't due to some big fluke with the ordering of the cell numbers

# %%
import os, sys

if os.path.basename(os.getcwd()) == 'code-base':
    os.chdir('../')
sys.path.append('code-base')

import numpy as np
import pandas as pd
import glob
import pprint
from scipy.stats import pearsonr
from datetime import datetime
from scipy.stats import ttest_ind
import seaborn as sns
from matplotlib import pyplot as plt
import re
from src.formation import FormationCell
import seaborn as sns

# %%
assert os.path.basename(os.getcwd()) == 'project-formation'

# %% [markdown]
# ## Configure plot settings

# %%
# Configure plot settings
plt.rc('font', **{'family'     : 'sans-serif',
                  'sans-serif' : ['Helvetica'],
                  'size': 18
                  })
plt.rc('figure', **{'autolayout' : True,
                    'figsize'    : (10, 8),
                    'facecolor'  : 'white'
                    })
plt.rc('xtick', labelsize='medium')
plt.rc('ytick', labelsize='medium')
plt.rc('axes',  labelsize='medium', grid=True)
plt.rc('axes',  titlesize='medium')
plt.rc('legend', fontsize='medium')



DPI = 600
VOLTAGE_LIMITS = (2.95, 4.25)
CAPACITY_LIMITS = (0, 3)

ORANGE = (1, 0.5, 0)
BLUE = (0, 0.5, 1)
BLACK = (0.0, 0.0, 0.0)
GREEN = (0, 0.75, 0)
ORANGE = (1, 0.5, 0)

# %% [markdown]
# ## Load resources

# %%
formation_cells = []
cellid_list = np.arange(1, 41)

for cellid in cellid_list:
    formation_cells.append(FormationCell(cellid))
    
for cell in formation_cells:
    print(cell)
# Out:
# Formation Cell 1
# Formation Cell 2
# Formation Cell 3
# Formation Cell 4
# Formation Cell 5
# Formation Cell 6
# Formation Cell 7
# Formation Cell 8
# Formation Cell 9
# Formation Cell 10
# Formation Cell 11
# Formation Cell 12
# Formation Cell 13
# Formation Cell 14
# Formation Cell 15
# Formation Cell 16
# Formation Cell 17
# Formation Cell 18
# Formation Cell 19
# Formation Cell 20
# Formation Cell 21
# Formation Cell 22
# Formation Cell 23
# Formation Cell 24
# Formation Cell 25
# Formation Cell 26
# Formation Cell 27
# Formation Cell 28
# Formation Cell 29
# Formation Cell 30
# Formation Cell 31
# Formation Cell 32
# Formation Cell 33
# Formation Cell 34
# Formation Cell 35
# Formation Cell 36
# Formation Cell 37
# Formation Cell 38
# Formation Cell 39
# Formation Cell 40

# %% [markdown]
# ## Get the summary statistics for each cell

# %%
all_summary_data = []

for cell in formation_cells:
    
    if cell.cellid == 9:
        continue
        
    print(f'Compiling data on cell #{cell.cellid}...')
    
    curr_summary = dict()

    curr_summary['cellid'] = cell.cellid
    curr_summary['channel_number'] = cell.get_channel_number()
    curr_summary['is_room_temp_aging'] = 1 if cell.is_room_temp() else 0
    curr_summary['is_baseline_formation'] = 1 if cell.is_baseline_formation() else 0
    
    # Add information from the formation cycles
    curr_summary.update(cell.get_formation_test_summary_statistics())
    curr_summary['form_coulombic_efficiency'] = curr_summary['form_final_discharge_capacity_ah'] / curr_summary['form_first_charge_capacity_ah']
    
    # Add the results from the aging test
    curr_summary.update(cell.get_aging_test_summary_statistics())
    
    # Add the eSOH fitting results for two different cycle numbers
    df_esoh = cell.get_esoh_fitting_results()
    df_esoh_c3 = df_esoh[df_esoh['cycle_number'] == 3].drop(columns=['cellid', 'cycle_number'])
    df_esoh_c56 = df_esoh[df_esoh['cycle_number'] == 56].drop(columns=['cellid', 'cycle_number'])
    curr_summary.update(df_esoh_c3.add_prefix('esoh_c3_').to_dict('records')[0])
    curr_summary.update(df_esoh_c56.add_prefix('esoh_c56_').to_dict('records')[0])
                                                
    curr_summary['is_plating'] = 1 if cell.is_plating() else 0
    curr_summary['swelling_severity'] = cell.get_swelling_severity()
    curr_summary['thickness_mm'] = cell.get_thickness()
    curr_summary['electrolyte_weight_g'] = cell.get_electrolyte_weight()
    
    all_summary_data.append(curr_summary)
    
df_corr = pd.DataFrame(all_summary_data)
# Out:
# Compiling data on cell #1...
# Compiling data on cell #2...
# Compiling data on cell #3...
# Compiling data on cell #4...
# Compiling data on cell #5...
# Compiling data on cell #6...
# Compiling data on cell #7...
# Compiling data on cell #8...
# Compiling data on cell #10...
# Compiling data on cell #11...
# Compiling data on cell #12...
# Compiling data on cell #13...
# Compiling data on cell #14...
# Compiling data on cell #15...
# Compiling data on cell #16...
# Compiling data on cell #17...
# Compiling data on cell #18...
# Compiling data on cell #19...
# Compiling data on cell #20...
# Compiling data on cell #21...
# Compiling data on cell #22...
# Compiling data on cell #23...
# Compiling data on cell #24...
# Compiling data on cell #25...
# Compiling data on cell #26...
# Compiling data on cell #27...
# Compiling data on cell #28...
# Compiling data on cell #29...
# Compiling data on cell #30...
# Compiling data on cell #31...
# Compiling data on cell #32...
# Compiling data on cell #33...
# Compiling data on cell #34...
# Compiling data on cell #35...
# Compiling data on cell #36...
# Compiling data on cell #37...
# Compiling data on cell #38...
# Compiling data on cell #39...
# Compiling data on cell #40...

# %%
df_corr.columns.values
# Out:
# array(['cellid', 'channel_number', 'is_room_temp_aging',
#        'is_baseline_formation',
#        'form_first_discharge_capacity_below_3p2v_ah',
#        'form_first_discharge_rest_voltage_rebound_1s',
#        'form_first_discharge_rest_voltage_rebound_10s',
#        'form_first_discharge_rest_voltage_rebound_1800s',
#        'form_last_charge_voltage_trace_cap_ah',
#        'form_last_charge_voltage_trace_voltage_v',
#        'form_last_charge_voltage_after_1s',
#        'form_last_charge_voltage_after_10s',
#        'form_last_charge_voltage_after_60s',
#        'form_first_charge_capacity_ah',
#        'form_first_discharge_capacity_ah', 'form_first_cycle_efficiency',
#        'form_final_discharge_capacity_ah',
#        'form_6hr_rest_delta_voltage_v_0_to_1_hr',
#        'form_6hr_rest_delta_voltage_v_0_to_2_hr',
#        'form_6hr_rest_delta_voltage_v_0_to_3_hr',
#        'form_6hr_rest_delta_voltage_v_0_to_4_hr',
#        'form_6hr_rest_delta_voltage_v_0_to_5_hr',
#        'form_6hr_rest_delta_voltage_v_0_to_6_hr',
#        'form_6hr_rest_delta_voltage_v_1_to_6_hr',
#        'form_6hr_rest_delta_voltage_v_2_to_6_hr',
#        'form_6hr_rest_delta_voltage_v_3_to_6_hr',
#        'form_6hr_rest_delta_voltage_v_4_to_6_hr',
#        'form_6hr_rest_delta_voltage_v_5_to_6_hr',
#        'form_c20_charge_qpp_ah', 'form_c20_charge_right_peak_v_per_ah',
#        'form_6hr_rest_delta_voltage_v', 'form_6hr_rest_voltage_v',
#        'form_6hr_rest_mv_per_day_steady',
#        'form_6hr_rest_mv_per_sec_initial',
#        'form_first_cv_hold_capacity_ah', 'form_coulombic_efficiency',
#        'initial_capacity', 'initial_capacity_std', 'cycles_to_50_pct',
#        'cycles_to_60_pct', 'cycles_to_70_pct', 'cycles_to_80_pct',
#        'var_q_c20_c56_c3_ah', 'var_q_c20_c56_c3_delta_q',
#        'var_q_c20_c56_c3_voltage_v', 'var_q_c20_c159_c3_ah',
#        'var_q_c20_c159_c3_delta_q', 'var_q_c20_c159_c3_voltage_v',
#        'var_q_c20_c262_c3_ah', 'var_q_c20_c262_c3_delta_q',
#        'var_q_c20_c262_c3_voltage_v', 'var_q_c20_c365_c3_ah',
#        'var_q_c20_c365_c3_delta_q', 'var_q_c20_c365_c3_voltage_v',
#        'var_q_c20_c468_c3_ah', 'var_q_c20_c468_c3_delta_q',
#        'var_q_c20_c468_c3_voltage_v', 'var_q_1c_c100_c10_ah',
#        'var_q_1c_c100_c10_delta_q', 'var_q_1c_c100_c10_voltage_v',
#        'c3_dch_cap_at_c2_ah', 'c3_dch_cap_at_c55_ah',
#        'c3_dch_cap_at_c158_ah', 'c3_dch_cap_at_c261_ah',
#        'c3_dch_cap_at_c364_ah', 'c3_dch_cap_at_c467_ah',
#        'c3_dch_cap_at_c520_ah', 'c20_dch_cap_at_c3_ah',
#        'c20_minus_c3_dch_cap_at_c3_ah', 'c20_over_c3_dch_cap_at_c3_ah',
#        'c20_dch_cap_at_c56_ah', 'c20_minus_c3_dch_cap_at_c56_ah',
#        'c20_over_c3_dch_cap_at_c56_ah', 'c20_dch_cap_at_c159_ah',
#        'c20_minus_c3_dch_cap_at_c159_ah',
#        'c20_over_c3_dch_cap_at_c159_ah', 'c20_dch_cap_at_c262_ah',
#        'c20_minus_c3_dch_cap_at_c262_ah',
#        'c20_over_c3_dch_cap_at_c262_ah', 'c20_dch_cap_at_c365_ah',
#        'c20_minus_c3_dch_cap_at_c365_ah',
#        'c20_over_c3_dch_cap_at_c365_ah', 'c20_dch_cap_at_c468_ah',
#        'c20_minus_c3_dch_cap_at_c468_ah',
#        'c20_over_c3_dch_cap_at_c468_ah', 'retention_at_c3',
#        'dcr_10s_0_soc_at_c3', 'dcr_3s_0_soc_at_c3', 'dcr_1s_0_soc_at_c3',
#        'dcr_10s_5_soc_at_c3', 'dcr_3s_5_soc_at_c3', 'dcr_1s_5_soc_at_c3',
#        'dcr_10s_7_soc_at_c3', 'dcr_3s_7_soc_at_c3', 'dcr_1s_7_soc_at_c3',
#        'dcr_10s_10_soc_at_c3', 'dcr_3s_10_soc_at_c3',
#        'dcr_1s_10_soc_at_c3', 'dcr_10s_15_soc_at_c3',
#        'dcr_3s_15_soc_at_c3', 'dcr_1s_15_soc_at_c3',
#        'dcr_10s_20_soc_at_c3', 'dcr_3s_20_soc_at_c3',
#        'dcr_1s_20_soc_at_c3', 'dcr_10s_30_soc_at_c3',
#        'dcr_3s_30_soc_at_c3', 'dcr_1s_30_soc_at_c3',
#        'dcr_10s_50_soc_at_c3', 'dcr_3s_50_soc_at_c3',
#        'dcr_1s_50_soc_at_c3', 'dcr_10s_70_soc_at_c3',
#        'dcr_3s_70_soc_at_c3', 'dcr_1s_70_soc_at_c3',
#        'dcr_10s_90_soc_at_c3', 'dcr_3s_90_soc_at_c3',
#        'dcr_1s_90_soc_at_c3', 'dcr_10s_100_soc_at_c3',
#        'dcr_3s_100_soc_at_c3', 'dcr_1s_100_soc_at_c3', 'retention_at_c50',
#        'dcr_10s_0_soc_at_c50', 'dcr_3s_0_soc_at_c50',
#        'dcr_1s_0_soc_at_c50', 'dcr_10s_5_soc_at_c50',
#        'dcr_3s_5_soc_at_c50', 'dcr_1s_5_soc_at_c50',
#        'dcr_10s_7_soc_at_c50', 'dcr_3s_7_soc_at_c50',
#        'dcr_1s_7_soc_at_c50', 'dcr_10s_10_soc_at_c50',
#        'dcr_3s_10_soc_at_c50', 'dcr_1s_10_soc_at_c50',
#        'dcr_10s_15_soc_at_c50', 'dcr_3s_15_soc_at_c50',
#        'dcr_1s_15_soc_at_c50', 'dcr_10s_20_soc_at_c50',
#        'dcr_3s_20_soc_at_c50', 'dcr_1s_20_soc_at_c50',
#        'dcr_10s_30_soc_at_c50', 'dcr_3s_30_soc_at_c50',
#        'dcr_1s_30_soc_at_c50', 'dcr_10s_50_soc_at_c50',
#        'dcr_3s_50_soc_at_c50', 'dcr_1s_50_soc_at_c50',
#        'dcr_10s_70_soc_at_c50', 'dcr_3s_70_soc_at_c50',
#        'dcr_1s_70_soc_at_c50', 'dcr_10s_90_soc_at_c50',
#        'dcr_3s_90_soc_at_c50', 'dcr_1s_90_soc_at_c50',
#        'dcr_10s_100_soc_at_c50', 'dcr_3s_100_soc_at_c50',
#        'dcr_1s_100_soc_at_c50', 'retention_at_c56',
#        'dcr_10s_0_soc_at_c56', 'dcr_3s_0_soc_at_c56',
#        'dcr_1s_0_soc_at_c56', 'dcr_10s_5_soc_at_c56',
#        'dcr_3s_5_soc_at_c56', 'dcr_1s_5_soc_at_c56',
#        'dcr_10s_7_soc_at_c56', 'dcr_3s_7_soc_at_c56',
#        'dcr_1s_7_soc_at_c56', 'dcr_10s_10_soc_at_c56',
#        'dcr_3s_10_soc_at_c56', 'dcr_1s_10_soc_at_c56',
#        'dcr_10s_15_soc_at_c56', 'dcr_3s_15_soc_at_c56',
#        'dcr_1s_15_soc_at_c56', 'dcr_10s_20_soc_at_c56',
#        'dcr_3s_20_soc_at_c56', 'dcr_1s_20_soc_at_c56',
#        'dcr_10s_30_soc_at_c56', 'dcr_3s_30_soc_at_c56',
#        'dcr_1s_30_soc_at_c56', 'dcr_10s_50_soc_at_c56',
#        'dcr_3s_50_soc_at_c56', 'dcr_1s_50_soc_at_c56',
#        'dcr_10s_70_soc_at_c56', 'dcr_3s_70_soc_at_c56',
#        'dcr_1s_70_soc_at_c56', 'dcr_10s_90_soc_at_c56',
#        'dcr_3s_90_soc_at_c56', 'dcr_1s_90_soc_at_c56',
#        'dcr_10s_100_soc_at_c56', 'dcr_3s_100_soc_at_c56',
#        'dcr_1s_100_soc_at_c56', 'retention_at_c100',
#        'dcr_10s_0_soc_at_c100', 'dcr_3s_0_soc_at_c100',
#        'dcr_1s_0_soc_at_c100', 'dcr_10s_5_soc_at_c100',
#        'dcr_3s_5_soc_at_c100', 'dcr_1s_5_soc_at_c100',
#        'dcr_10s_7_soc_at_c100', 'dcr_3s_7_soc_at_c100',
#        'dcr_1s_7_soc_at_c100', 'dcr_10s_10_soc_at_c100',
#        'dcr_3s_10_soc_at_c100', 'dcr_1s_10_soc_at_c100',
#        'dcr_10s_15_soc_at_c100', 'dcr_3s_15_soc_at_c100',
#        'dcr_1s_15_soc_at_c100', 'dcr_10s_20_soc_at_c100',
#        'dcr_3s_20_soc_at_c100', 'dcr_1s_20_soc_at_c100',
#        'dcr_10s_30_soc_at_c100', 'dcr_3s_30_soc_at_c100',
#        'dcr_1s_30_soc_at_c100', 'dcr_10s_50_soc_at_c100',
#        'dcr_3s_50_soc_at_c100', 'dcr_1s_50_soc_at_c100',
#        'dcr_10s_70_soc_at_c100', 'dcr_3s_70_soc_at_c100',
#        'dcr_1s_70_soc_at_c100', 'dcr_10s_90_soc_at_c100',
#        'dcr_3s_90_soc_at_c100', 'dcr_1s_90_soc_at_c100',
#        'dcr_10s_100_soc_at_c100', 'dcr_3s_100_soc_at_c100',
#        'dcr_1s_100_soc_at_c100', 'retention_at_c150',
#        'dcr_10s_0_soc_at_c150', 'dcr_3s_0_soc_at_c150',
#        'dcr_1s_0_soc_at_c150', 'dcr_10s_5_soc_at_c150',
#        'dcr_3s_5_soc_at_c150', 'dcr_1s_5_soc_at_c150',
#        'dcr_10s_7_soc_at_c150', 'dcr_3s_7_soc_at_c150',
#        'dcr_1s_7_soc_at_c150', 'dcr_10s_10_soc_at_c150',
#        'dcr_3s_10_soc_at_c150', 'dcr_1s_10_soc_at_c150',
#        'dcr_10s_15_soc_at_c150', 'dcr_3s_15_soc_at_c150',
#        'dcr_1s_15_soc_at_c150', 'dcr_10s_20_soc_at_c150',
#        'dcr_3s_20_soc_at_c150', 'dcr_1s_20_soc_at_c150',
#        'dcr_10s_30_soc_at_c150', 'dcr_3s_30_soc_at_c150',
#        'dcr_1s_30_soc_at_c150', 'dcr_10s_50_soc_at_c150',
#        'dcr_3s_50_soc_at_c150', 'dcr_1s_50_soc_at_c150',
#        'dcr_10s_70_soc_at_c150', 'dcr_3s_70_soc_at_c150',
#        'dcr_1s_70_soc_at_c150', 'dcr_10s_90_soc_at_c150',
#        'dcr_3s_90_soc_at_c150', 'dcr_1s_90_soc_at_c150',
#        'dcr_10s_100_soc_at_c150', 'dcr_3s_100_soc_at_c150',
#        'dcr_1s_100_soc_at_c150', 'retention_at_c159',
#        'dcr_10s_0_soc_at_c159', 'dcr_3s_0_soc_at_c159',
#        'dcr_1s_0_soc_at_c159', 'dcr_10s_5_soc_at_c159',
#        'dcr_3s_5_soc_at_c159', 'dcr_1s_5_soc_at_c159',
#        'dcr_10s_7_soc_at_c159', 'dcr_3s_7_soc_at_c159',
#        'dcr_1s_7_soc_at_c159', 'dcr_10s_10_soc_at_c159',
#        'dcr_3s_10_soc_at_c159', 'dcr_1s_10_soc_at_c159',
#        'dcr_10s_15_soc_at_c159', 'dcr_3s_15_soc_at_c159',
#        'dcr_1s_15_soc_at_c159', 'dcr_10s_20_soc_at_c159',
#        'dcr_3s_20_soc_at_c159', 'dcr_1s_20_soc_at_c159',
#        'dcr_10s_30_soc_at_c159', 'dcr_3s_30_soc_at_c159',
#        'dcr_1s_30_soc_at_c159', 'dcr_10s_50_soc_at_c159',
#        'dcr_3s_50_soc_at_c159', 'dcr_1s_50_soc_at_c159',
#        'dcr_10s_70_soc_at_c159', 'dcr_3s_70_soc_at_c159',
#        'dcr_1s_70_soc_at_c159', 'dcr_10s_90_soc_at_c159',
#        'dcr_3s_90_soc_at_c159', 'dcr_1s_90_soc_at_c159',
#        'dcr_10s_100_soc_at_c159', 'dcr_3s_100_soc_at_c159',
#        'dcr_1s_100_soc_at_c159', 'retention_at_c200',
#        'dcr_10s_0_soc_at_c200', 'dcr_3s_0_soc_at_c200',
#        'dcr_1s_0_soc_at_c200', 'dcr_10s_5_soc_at_c200',
#        'dcr_3s_5_soc_at_c200', 'dcr_1s_5_soc_at_c200',
#        'dcr_10s_7_soc_at_c200', 'dcr_3s_7_soc_at_c200',
#        'dcr_1s_7_soc_at_c200', 'dcr_10s_10_soc_at_c200',
#        'dcr_3s_10_soc_at_c200', 'dcr_1s_10_soc_at_c200',
#        'dcr_10s_15_soc_at_c200', 'dcr_3s_15_soc_at_c200',
#        'dcr_1s_15_soc_at_c200', 'dcr_10s_20_soc_at_c200',
#        'dcr_3s_20_soc_at_c200', 'dcr_1s_20_soc_at_c200',
#        'dcr_10s_30_soc_at_c200', 'dcr_3s_30_soc_at_c200',
#        'dcr_1s_30_soc_at_c200', 'dcr_10s_50_soc_at_c200',
#        'dcr_3s_50_soc_at_c200', 'dcr_1s_50_soc_at_c200',
#        'dcr_10s_70_soc_at_c200', 'dcr_3s_70_soc_at_c200',
#        'dcr_1s_70_soc_at_c200', 'dcr_10s_90_soc_at_c200',
#        'dcr_3s_90_soc_at_c200', 'dcr_1s_90_soc_at_c200',
#        'dcr_10s_100_soc_at_c200', 'dcr_3s_100_soc_at_c200',
#        'dcr_1s_100_soc_at_c200', 'retention_at_c250',
#        'dcr_10s_0_soc_at_c250', 'dcr_3s_0_soc_at_c250',
#        'dcr_1s_0_soc_at_c250', 'dcr_10s_5_soc_at_c250',
#        'dcr_3s_5_soc_at_c250', 'dcr_1s_5_soc_at_c250',
#        'dcr_10s_7_soc_at_c250', 'dcr_3s_7_soc_at_c250',
#        'dcr_1s_7_soc_at_c250', 'dcr_10s_10_soc_at_c250',
#        'dcr_3s_10_soc_at_c250', 'dcr_1s_10_soc_at_c250',
#        'dcr_10s_15_soc_at_c250', 'dcr_3s_15_soc_at_c250',
#        'dcr_1s_15_soc_at_c250', 'dcr_10s_20_soc_at_c250',
#        'dcr_3s_20_soc_at_c250', 'dcr_1s_20_soc_at_c250',
#        'dcr_10s_30_soc_at_c250', 'dcr_3s_30_soc_at_c250',
#        'dcr_1s_30_soc_at_c250', 'dcr_10s_50_soc_at_c250',
#        'dcr_3s_50_soc_at_c250', 'dcr_1s_50_soc_at_c250',
#        'dcr_10s_70_soc_at_c250', 'dcr_3s_70_soc_at_c250',
#        'dcr_1s_70_soc_at_c250', 'dcr_10s_90_soc_at_c250',
#        'dcr_3s_90_soc_at_c250', 'dcr_1s_90_soc_at_c250',
#        'dcr_10s_100_soc_at_c250', 'dcr_3s_100_soc_at_c250',
#        'dcr_1s_100_soc_at_c250', 'retention_at_c262',
#        'dcr_10s_0_soc_at_c262', 'dcr_3s_0_soc_at_c262',
#        'dcr_1s_0_soc_at_c262', 'dcr_10s_5_soc_at_c262',
#        'dcr_3s_5_soc_at_c262', 'dcr_1s_5_soc_at_c262',
#        'dcr_10s_7_soc_at_c262', 'dcr_3s_7_soc_at_c262',
#        'dcr_1s_7_soc_at_c262', 'dcr_10s_10_soc_at_c262',
#        'dcr_3s_10_soc_at_c262', 'dcr_1s_10_soc_at_c262',
#        'dcr_10s_15_soc_at_c262', 'dcr_3s_15_soc_at_c262',
#        'dcr_1s_15_soc_at_c262', 'dcr_10s_20_soc_at_c262',
#        'dcr_3s_20_soc_at_c262', 'dcr_1s_20_soc_at_c262',
#        'dcr_10s_30_soc_at_c262', 'dcr_3s_30_soc_at_c262',
#        'dcr_1s_30_soc_at_c262', 'dcr_10s_50_soc_at_c262',
#        'dcr_3s_50_soc_at_c262', 'dcr_1s_50_soc_at_c262',
#        'dcr_10s_70_soc_at_c262', 'dcr_3s_70_soc_at_c262',
#        'dcr_1s_70_soc_at_c262', 'dcr_10s_90_soc_at_c262',
#        'dcr_3s_90_soc_at_c262', 'dcr_1s_90_soc_at_c262',
#        'dcr_10s_100_soc_at_c262', 'dcr_3s_100_soc_at_c262',
#        'dcr_1s_100_soc_at_c262', 'retention_at_c300',
#        'dcr_10s_0_soc_at_c300', 'dcr_3s_0_soc_at_c300',
#        'dcr_1s_0_soc_at_c300', 'dcr_10s_5_soc_at_c300',
#        'dcr_3s_5_soc_at_c300', 'dcr_1s_5_soc_at_c300',
#        'dcr_10s_7_soc_at_c300', 'dcr_3s_7_soc_at_c300',
#        'dcr_1s_7_soc_at_c300', 'dcr_10s_10_soc_at_c300',
#        'dcr_3s_10_soc_at_c300', 'dcr_1s_10_soc_at_c300',
#        'dcr_10s_15_soc_at_c300', 'dcr_3s_15_soc_at_c300',
#        'dcr_1s_15_soc_at_c300', 'dcr_10s_20_soc_at_c300',
#        'dcr_3s_20_soc_at_c300', 'dcr_1s_20_soc_at_c300',
#        'dcr_10s_30_soc_at_c300', 'dcr_3s_30_soc_at_c300',
#        'dcr_1s_30_soc_at_c300', 'dcr_10s_50_soc_at_c300',
#        'dcr_3s_50_soc_at_c300', 'dcr_1s_50_soc_at_c300',
#        'dcr_10s_70_soc_at_c300', 'dcr_3s_70_soc_at_c300',
#        'dcr_1s_70_soc_at_c300', 'dcr_10s_90_soc_at_c300',
#        'dcr_3s_90_soc_at_c300', 'dcr_1s_90_soc_at_c300',
#        'dcr_10s_100_soc_at_c300', 'dcr_3s_100_soc_at_c300',
#        'dcr_1s_100_soc_at_c300', 'retention_at_c350',
#        'dcr_10s_0_soc_at_c350', 'dcr_3s_0_soc_at_c350',
#        'dcr_1s_0_soc_at_c350', 'dcr_10s_5_soc_at_c350',
#        'dcr_3s_5_soc_at_c350', 'dcr_1s_5_soc_at_c350',
#        'dcr_10s_7_soc_at_c350', 'dcr_3s_7_soc_at_c350',
#        'dcr_1s_7_soc_at_c350', 'dcr_10s_10_soc_at_c350',
#        'dcr_3s_10_soc_at_c350', 'dcr_1s_10_soc_at_c350',
#        'dcr_10s_15_soc_at_c350', 'dcr_3s_15_soc_at_c350',
#        'dcr_1s_15_soc_at_c350', 'dcr_10s_20_soc_at_c350',
#        'dcr_3s_20_soc_at_c350', 'dcr_1s_20_soc_at_c350',
#        'dcr_10s_30_soc_at_c350', 'dcr_3s_30_soc_at_c350',
#        'dcr_1s_30_soc_at_c350', 'dcr_10s_50_soc_at_c350',
#        'dcr_3s_50_soc_at_c350', 'dcr_1s_50_soc_at_c350',
#        'dcr_10s_70_soc_at_c350', 'dcr_3s_70_soc_at_c350',
#        'dcr_1s_70_soc_at_c350', 'dcr_10s_90_soc_at_c350',
#        'dcr_3s_90_soc_at_c350', 'dcr_1s_90_soc_at_c350',
#        'dcr_10s_100_soc_at_c350', 'dcr_3s_100_soc_at_c350',
#        'dcr_1s_100_soc_at_c350', 'retention_at_c365',
#        'dcr_10s_0_soc_at_c365', 'dcr_3s_0_soc_at_c365',
#        'dcr_1s_0_soc_at_c365', 'dcr_10s_5_soc_at_c365',
#        'dcr_3s_5_soc_at_c365', 'dcr_1s_5_soc_at_c365',
#        'dcr_10s_7_soc_at_c365', 'dcr_3s_7_soc_at_c365',
#        'dcr_1s_7_soc_at_c365', 'dcr_10s_10_soc_at_c365',
#        'dcr_3s_10_soc_at_c365', 'dcr_1s_10_soc_at_c365',
#        'dcr_10s_15_soc_at_c365', 'dcr_3s_15_soc_at_c365',
#        'dcr_1s_15_soc_at_c365', 'dcr_10s_20_soc_at_c365',
#        'dcr_3s_20_soc_at_c365', 'dcr_1s_20_soc_at_c365',
#        'dcr_10s_30_soc_at_c365', 'dcr_3s_30_soc_at_c365',
#        'dcr_1s_30_soc_at_c365', 'dcr_10s_50_soc_at_c365',
#        'dcr_3s_50_soc_at_c365', 'dcr_1s_50_soc_at_c365',
#        'dcr_10s_70_soc_at_c365', 'dcr_3s_70_soc_at_c365',
#        'dcr_1s_70_soc_at_c365', 'dcr_10s_90_soc_at_c365',
#        'dcr_3s_90_soc_at_c365', 'dcr_1s_90_soc_at_c365',
#        'dcr_10s_100_soc_at_c365', 'dcr_3s_100_soc_at_c365',
#        'dcr_1s_100_soc_at_c365', 'retention_at_c400',
#        'dcr_10s_0_soc_at_c400', 'dcr_3s_0_soc_at_c400',
#        'dcr_1s_0_soc_at_c400', 'dcr_10s_5_soc_at_c400',
#        'dcr_3s_5_soc_at_c400', 'dcr_1s_5_soc_at_c400',
#        'dcr_10s_7_soc_at_c400', 'dcr_3s_7_soc_at_c400',
#        'dcr_1s_7_soc_at_c400', 'dcr_10s_10_soc_at_c400',
#        'dcr_3s_10_soc_at_c400', 'dcr_1s_10_soc_at_c400',
#        'dcr_10s_15_soc_at_c400', 'dcr_3s_15_soc_at_c400',
#        'dcr_1s_15_soc_at_c400', 'dcr_10s_20_soc_at_c400',
#        'dcr_3s_20_soc_at_c400', 'dcr_1s_20_soc_at_c400',
#        'dcr_10s_30_soc_at_c400', 'dcr_3s_30_soc_at_c400',
#        'dcr_1s_30_soc_at_c400', 'dcr_10s_50_soc_at_c400',
#        'dcr_3s_50_soc_at_c400', 'dcr_1s_50_soc_at_c400',
#        'dcr_10s_70_soc_at_c400', 'dcr_3s_70_soc_at_c400',
#        'dcr_1s_70_soc_at_c400', 'dcr_10s_90_soc_at_c400',
#        'dcr_3s_90_soc_at_c400', 'dcr_1s_90_soc_at_c400',
#        'dcr_10s_100_soc_at_c400', 'dcr_3s_100_soc_at_c400',
#        'dcr_1s_100_soc_at_c400', 'retention_at_c450',
#        'dcr_10s_0_soc_at_c450', 'dcr_3s_0_soc_at_c450',
#        'dcr_1s_0_soc_at_c450', 'dcr_10s_5_soc_at_c450',
#        'dcr_3s_5_soc_at_c450', 'dcr_1s_5_soc_at_c450',
#        'dcr_10s_7_soc_at_c450', 'dcr_3s_7_soc_at_c450',
#        'dcr_1s_7_soc_at_c450', 'dcr_10s_10_soc_at_c450',
#        'dcr_3s_10_soc_at_c450', 'dcr_1s_10_soc_at_c450',
#        'dcr_10s_15_soc_at_c450', 'dcr_3s_15_soc_at_c450',
#        'dcr_1s_15_soc_at_c450', 'dcr_10s_20_soc_at_c450',
#        'dcr_3s_20_soc_at_c450', 'dcr_1s_20_soc_at_c450',
#        'dcr_10s_30_soc_at_c450', 'dcr_3s_30_soc_at_c450',
#        'dcr_1s_30_soc_at_c450', 'dcr_10s_50_soc_at_c450',
#        'dcr_3s_50_soc_at_c450', 'dcr_1s_50_soc_at_c450',
#        'dcr_10s_70_soc_at_c450', 'dcr_3s_70_soc_at_c450',
#        'dcr_1s_70_soc_at_c450', 'dcr_10s_90_soc_at_c450',
#        'dcr_3s_90_soc_at_c450', 'dcr_1s_90_soc_at_c450',
#        'dcr_10s_100_soc_at_c450', 'dcr_3s_100_soc_at_c450',
#        'dcr_1s_100_soc_at_c450', 'dcr_10s_0_soc_at_70_pct',
#        'dcr_3s_0_soc_at_70_pct', 'dcr_1s_0_soc_at_70_pct',
#        'dcr_10s_5_soc_at_70_pct', 'dcr_3s_5_soc_at_70_pct',
#        'dcr_1s_5_soc_at_70_pct', 'dcr_10s_7_soc_at_70_pct',
#        'dcr_3s_7_soc_at_70_pct', 'dcr_1s_7_soc_at_70_pct',
#        'dcr_10s_10_soc_at_70_pct', 'dcr_3s_10_soc_at_70_pct',
#        'dcr_1s_10_soc_at_70_pct', 'dcr_10s_15_soc_at_70_pct',
#        'dcr_3s_15_soc_at_70_pct', 'dcr_1s_15_soc_at_70_pct',
#        'dcr_10s_20_soc_at_70_pct', 'dcr_3s_20_soc_at_70_pct',
#        'dcr_1s_20_soc_at_70_pct', 'dcr_10s_30_soc_at_70_pct',
#        'dcr_3s_30_soc_at_70_pct', 'dcr_1s_30_soc_at_70_pct',
#        'dcr_10s_50_soc_at_70_pct', 'dcr_3s_50_soc_at_70_pct',
#        'dcr_1s_50_soc_at_70_pct', 'dcr_10s_70_soc_at_70_pct',
#        'dcr_3s_70_soc_at_70_pct', 'dcr_1s_70_soc_at_70_pct',
#        'dcr_10s_90_soc_at_70_pct', 'dcr_3s_90_soc_at_70_pct',
#        'dcr_1s_90_soc_at_70_pct', 'dcr_10s_100_soc_at_70_pct',
#        'dcr_3s_100_soc_at_70_pct', 'dcr_1s_100_soc_at_70_pct',
#        'esoh_c3_y100', 'esoh_c3_Cp', 'esoh_c3_x100', 'esoh_c3_Cn',
#        'esoh_c3_Qcomp', 'esoh_c3_x0', 'esoh_c3_y0', 'esoh_c3_Qfull',
#        'esoh_c3_pos_excess', 'esoh_c3_neg_excess', 'esoh_c3_RMSE_mV',
#        'esoh_c3_np_ratio', 'esoh_c3_n_li', 'esoh_c3_LLI',
#        'esoh_c3_LAM_PE', 'esoh_c3_LAM_NE', 'esoh_c3_C20_loss',
#        'esoh_c3_Cn_pf', 'esoh_c3_x100_pf', 'esoh_c56_y100', 'esoh_c56_Cp',
#        'esoh_c56_x100', 'esoh_c56_Cn', 'esoh_c56_Qcomp', 'esoh_c56_x0',
#        'esoh_c56_y0', 'esoh_c56_Qfull', 'esoh_c56_pos_excess',
#        'esoh_c56_neg_excess', 'esoh_c56_RMSE_mV', 'esoh_c56_np_ratio',
#        'esoh_c56_n_li', 'esoh_c56_LLI', 'esoh_c56_LAM_PE',
#        'esoh_c56_LAM_NE', 'esoh_c56_C20_loss', 'esoh_c56_Cn_pf',
#        'esoh_c56_x100_pf', 'is_plating', 'swelling_severity',
#        'thickness_mm', 'electrolyte_weight_g', 'var_q_c20_c521_c3_ah',
#        'var_q_c20_c521_c3_delta_q', 'var_q_c20_c521_c3_voltage_v',
#        'c20_dch_cap_at_c521_ah', 'c20_minus_c3_dch_cap_at_c521_ah',
#        'c20_over_c3_dch_cap_at_c521_ah', 'var_q_c20_c418_c3_ah',
#        'var_q_c20_c418_c3_delta_q', 'var_q_c20_c418_c3_voltage_v',
#        'c3_dch_cap_at_c417_ah', 'c20_dch_cap_at_c418_ah',
#        'c20_minus_c3_dch_cap_at_c418_ah',
#        'c20_over_c3_dch_cap_at_c418_ah', 'var_q_c20_c471_c3_ah',
#        'var_q_c20_c471_c3_delta_q', 'var_q_c20_c471_c3_voltage_v',
#        'c3_dch_cap_at_c470_ah', 'c20_dch_cap_at_c471_ah',
#        'c20_minus_c3_dch_cap_at_c471_ah',
#        'c20_over_c3_dch_cap_at_c471_ah', 'var_q_c20_c524_c3_ah',
#        'var_q_c20_c524_c3_delta_q', 'var_q_c20_c524_c3_voltage_v',
#        'var_q_c20_c577_c3_ah', 'var_q_c20_c577_c3_delta_q',
#        'var_q_c20_c577_c3_voltage_v', 'c3_dch_cap_at_c523_ah',
#        'c3_dch_cap_at_c576_ah', 'c20_dch_cap_at_c524_ah',
#        'c20_minus_c3_dch_cap_at_c524_ah',
#        'c20_over_c3_dch_cap_at_c524_ah', 'c20_dch_cap_at_c577_ah',
#        'c20_minus_c3_dch_cap_at_c577_ah',
#        'c20_over_c3_dch_cap_at_c577_ah', 'c3_dch_cap_at_c629_ah',
#        'var_q_c20_c630_c3_ah', 'var_q_c20_c630_c3_delta_q',
#        'var_q_c20_c630_c3_voltage_v', 'c20_dch_cap_at_c630_ah',
#        'c20_minus_c3_dch_cap_at_c630_ah',
#        'c20_over_c3_dch_cap_at_c630_ah', 'var_q_c20_c574_c3_ah',
#        'var_q_c20_c574_c3_delta_q', 'var_q_c20_c574_c3_voltage_v',
#        'c3_dch_cap_at_c573_ah', 'c20_dch_cap_at_c574_ah',
#        'c20_minus_c3_dch_cap_at_c574_ah',
#        'c20_over_c3_dch_cap_at_c574_ah'], dtype=object)

# %%
df_corr
# Out:
#     cellid  channel_number  is_room_temp_aging  is_baseline_formation  \
# 0        1            22.0                   0                      1
# 1        2            23.0                   0                      1
# 2        3            24.0                   0                      1
# 3        4            25.0                   0                      1
# 4        5            26.0                   0                      1
# 5        6            27.0                   0                      1
# 6        7            28.0                   0                      1
# 7        8            29.0                   0                      1
# 8       10            31.0                   0                      1
# 9       11             1.0                   1                      1
# 10      12             2.0                   1                      1
# 11      13             3.0                   1                      1
# 12      14             4.0                   1                      1
# 13      15             5.0                   1                      1
# 14      16             6.0                   1                      1
# 15      17             7.0                   1                      1
# 16      18             8.0                   1                      1
# 17      19            10.0                   1                      1
# 18      20            11.0                   1                      1
# 19      21            12.0                   1                      0
# 20      22            13.0                   1                      0
# 21      23            14.0                   1                      0
# 22      24            15.0                   1                      0
# 23      25            16.0                   1                      0
# 24      26            17.0                   1                      0
# 25      27            18.0                   1                      0
# 26      28            19.0                   1                      0
# 27      29            20.0                   1                      0
# 28      30            21.0                   1                      0
# 29      31            32.0                   0                      0
# 30      32            33.0                   0                      0
# 31      33            34.0                   0                      0
# 32      34            35.0                   0                      0
# 33      35            36.0                   0                      0
# 34      36            37.0                   0                      0
# 35      37            38.0                   0                      0
# 36      38            39.0                   0                      0
# 37      39            40.0                   0                      0
# 38      40            41.0                   0                      0
#
#     form_first_discharge_capacity_below_3p2v_ah  \
# 0                                      0.077820
# 1                                      0.073791
# 2                                      0.074725
# 3                                      0.069433
# 4                                      0.073127
# 5                                      0.071483
# 6                                      0.076523
# 7                                      0.066771
# 8                                      0.070995
# 9                                      0.076570
# 10                                     0.076687
# 11                                     0.072891
# 12                                     0.078141
# 13                                     0.080460
# 14                                     0.074184
# 15                                     0.069909
# 16                                     0.070156
# 17                                     0.075486
# 18                                     0.072030
# 19                                     0.028163
# 20                                     0.026366
# 21                                     0.023131
# 22                                     0.025130
# 23                                     0.023776
# 24                                     0.023979
# 25                                     0.022726
# 26                                     0.024725
# 27                                     0.025192
# 28                                     0.022361
# 29                                     0.025480
# 30                                     0.023201
# 31                                     0.023901
# 32                                     0.023699
# 33                                     0.024648
# 34                                     0.024111
# 35                                     0.026001
# 36                                     0.023123
# 37                                     0.023870
# 38                                     0.024865
#
#     form_first_discharge_rest_voltage_rebound_1s  \
# 0                                       3.010586
# 1                                       3.011151
# 2                                       3.010842
# 3                                       3.010670
# 4                                       3.010769
# 5                                       3.010406
# 6                                       3.010416
# 7                                       3.011265
# 8                                       3.010797
# 9                                       3.010713
# 10                                      3.010702
# 11                                      3.010583
# 12                                      3.010407
# 13                                      3.010554
# 14                                      3.011118
# 15                                      3.010926
# 16                                      3.010845
# 17                                      3.010630
# 18                                      3.010519
# 19                                           NaN
# 20                                           NaN
# 21                                           NaN
# 22                                           NaN
# 23                                           NaN
# 24                                           NaN
# 25                                           NaN
# 26                                           NaN
# 27                                           NaN
# 28                                           NaN
# 29                                           NaN
# 30                                           NaN
# 31                                           NaN
# 32                                           NaN
# 33                                           NaN
# 34                                           NaN
# 35                                           NaN
# 36                                           NaN
# 37                                           NaN
# 38                                           NaN
#
#     form_first_discharge_rest_voltage_rebound_10s  \
# 0                                        3.057576
# 1                                        3.061895
# 2                                        3.060853
# 3                                        3.059812
# 4                                        3.060117
# 5                                        3.054375
# 6                                        3.057246
# 7                                        3.062353
# 8                                        3.059710
# 9                                        3.057475
# 10                                       3.058745
# 11                                       3.057551
# 12                                       3.055772
# 13                                       3.056560
# 14                                       3.062251
# 15                                       3.058923
# 16                                       3.060193
# 17                                       3.058719
# 18                                       3.058287
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
# 23                                            NaN
# 24                                            NaN
# 25                                            NaN
# 26                                            NaN
# 27                                            NaN
# 28                                            NaN
# 29                                            NaN
# 30                                            NaN
# 31                                            NaN
# 32                                            NaN
# 33                                            NaN
# 34                                            NaN
# 35                                            NaN
# 36                                            NaN
# 37                                            NaN
# 38                                            NaN
#
#     form_first_discharge_rest_voltage_rebound_1800s  \
# 0                                          3.382315
# 1                                          3.388266
# 2                                          3.386511
# 3                                          3.386282
# 4                                          3.384222
# 5                                          3.377432
# 6                                          3.381247
# 7                                          3.385901
# 8                                          3.384146
# 9                                          3.380560
# 10                                         3.382925
# 11                                         3.378958
# 12                                         3.380407
# 13                                         3.382010
# 14                                         3.388037
# 15                                         3.383230
# 16                                         3.382849
# 17                                         3.383230
# 18                                         3.384909
# 19                                              NaN
# 20                                              NaN
# 21                                              NaN
# 22                                              NaN
# 23                                              NaN
# 24                                              NaN
# 25                                              NaN
# 26                                              NaN
# 27                                              NaN
# 28                                              NaN
# 29                                              NaN
# 30                                              NaN
# 31                                              NaN
# 32                                              NaN
# 33                                              NaN
# 34                                              NaN
# 35                                              NaN
# 36                                              NaN
# 37                                              NaN
# 38                                              NaN
#
#                 form_last_charge_voltage_trace_cap_ah  \
# 0   1559    2.185772
# 1560    2.195145
# 1561    2.20...
# 1   1554    2.179028
# 1555    2.188387
# 1556    2.19...
# 2   1566    2.179772
# 1567    2.189165
# 1568    2.19...
# 3   1557    2.158946
# 1558    2.168266
# 1559    2.17...
# 4   1557    2.184033
# 1558    2.193558
# 1559    2.20...
# 5   1557    2.152492
# 1558    2.161824
# 1559    2.17...
# 6   1556    2.179185
# 1557    2.188594
# 1558    2.19...
# 7   1557    2.189254
# 1558    2.198621
# 1559    2.20...
# 8   1554    2.179605
# 1555    2.188927
# 1556    2.19...
# 9   1560    2.187236
# 1561    2.196766
# 1562    2.20...
# 10  1555    2.182917
# 1556    2.192197
# 1557    2.20...
# 11  1558    2.193936
# 1559    2.203236
# 1560    2.21...
# 12  1558    2.172220
# 1559    2.181403
# 1560    2.19...
# 13  1556    2.176391
# 1557    2.185731
# 1558    2.19...
# 14  1550    2.169211
# 1551    2.178451
# 1552    2.18...
# 15  1563    2.193127
# 1564    2.202356
# 1565    2.21...
# 16  1553    2.169679
# 1554    2.179026
# 1555    2.18...
# 17  1554    2.172197
# 1555    2.181601
# 1556    2.19...
# 18  1556    2.182673
# 1557    2.192039
# 1558    2.20...
# 19  1585    1.966678
# 1586    1.976075
# 1587    1.98...
# 20  1581    1.973919
# 1582    1.983004
# 1583    1.99...
# 21  1534    1.972065
# 1535    1.981402
# 1536    1.99...
# 22  1557    1.971954
# 1558    1.981158
# 1559    1.99...
# 23  1550    1.980823
# 1551    1.990100
# 1552    1.99...
# 24  1533    1.974271
# 1534    1.983285
# 1535    1.99...
# 25  1539    1.973394
# 1540    1.982550
# 1541    1.99...
# 26  1542    1.963846
# 1543    1.972884
# 1544    1.98...
# 27  1556    1.969077
# 1557    1.978273
# 1558    1.98...
# 28  1530    1.964091
# 1531    1.973330
# 1532    1.98...
# 29  1567    1.961556
# 1568    1.970893
# 1569    1.97...
# 30  1539    1.977728
# 1540    1.986781
# 1541    1.99...
# 31  1544    1.970776
# 1545    1.979959
# 1546    1.98...
# 32  1526    1.966744
# 1527    1.976075
# 1528    1.98...
# 33  1558    1.970936
# 1559    1.980070
# 1560    1.98...
# 34  1548    1.971445
# 1549    1.980422
# 1550    1.98...
# 35  1568    1.951641
# 1569    1.961038
# 1570    1.97...
# 36  1538    1.974447
# 1539    1.983374
# 1540    1.99...
# 37  1538    1.966953
# 1539    1.976195
# 1540    1.98...
# 38  1533    1.963046
# 1534    1.972405
# 1535    1.98...
#
#              form_last_charge_voltage_trace_voltage_v  ...  \
# 0   1559    4.102388
# 1560    4.107424
# 1561    4.11...  ...
# 1   1554    4.102846
# 1555    4.107958
# 1556    4.11...  ...
# 2   1566    4.104143
# 1567    4.109178
# 1568    4.11...  ...
# 3   1557    4.100328
# 1558    4.105364
# 1559    4.11...  ...
# 4   1557    4.101549
# 1558    4.106584
# 1559    4.11...  ...
# 5   1557    4.100786
# 1558    4.105898
# 1559    4.11...  ...
# 6   1556    4.102083
# 1557    4.107195
# 1558    4.11...  ...
# 7   1557    4.104829
# 1558    4.109865
# 1559    4.11...  ...
# 8   1554    4.103609
# 1555    4.108644
# 1556    4.11...  ...
# 9   1560    4.102617
# 1561    4.107729
# 1562    4.11...  ...
# 10  1555    4.100557
# 1556    4.105592
# 1557    4.11...  ...
# 11  1558    4.101778
# 1559    4.106889
# 1560    4.11...  ...
# 12  1558    4.100328
# 1559    4.105364
# 1560    4.11...  ...
# 13  1556    4.103456
# 1557    4.108568
# 1558    4.11...  ...
# 14  1550    4.100786
# 1551    4.105821
# 1552    4.11...  ...
# 15  1563    4.103532
# 1564    4.108568
# 1565    4.11...  ...
# 16  1553    4.101015
# 1554    4.106050
# 1555    4.11...  ...
# 17  1554    4.102159
# 1555    4.107271
# 1556    4.11...  ...
# 18  1556    4.101472
# 1557    4.106584
# 1558    4.11...  ...
# 19  1585    4.103380
# 1586    4.108415
# 1587    4.11...  ...
# 20  1581    4.103456
# 1582    4.108492
# 1583    4.11...  ...
# 21  1534    4.101015
# 1535    4.106127
# 1536    4.11...  ...
# 22  1557    4.104829
# 1558    4.109865
# 1559    4.11...  ...
# 23  1550    4.102159
# 1551    4.107195
# 1552    4.11...  ...
# 24  1533    4.103685
# 1534    4.108721
# 1535    4.11...  ...
# 25  1539    4.102770
# 1540    4.107805
# 1541    4.11...  ...
# 26  1542    4.102998
# 1543    4.108034
# 1544    4.11...  ...
# 27  1556    4.100633
# 1557    4.105669
# 1558    4.11...  ...
# 28  1530    4.101091
# 1531    4.106203
# 1532    4.11...  ...
# 29  1567    4.102541
# 1568    4.107652
# 1569    4.11...  ...
# 30  1539    4.103304
# 1540    4.108339
# 1541    4.11...  ...
# 31  1544    4.102159
# 1545    4.107195
# 1546    4.11...  ...
# 32  1526    4.100175
# 1527    4.105211
# 1528    4.11...  ...
# 33  1558    4.104753
# 1559    4.109789
# 1560    4.11...  ...
# 34  1548    4.103456
# 1549    4.108492
# 1550    4.11...  ...
# 35  1568    4.100328
# 1569    4.105516
# 1570    4.11...  ...
# 36  1538    4.101472
# 1539    4.106584
# 1540    4.11...  ...
# 37  1538    4.104067
# 1539    4.109102
# 1540    4.11...  ...
# 38  1533    4.102235
# 1534    4.107347
# 1535    4.11...  ...
#
#     c20_dch_cap_at_c630_ah  c20_minus_c3_dch_cap_at_c630_ah  \
# 0                      NaN                              NaN
# 1                      NaN                              NaN
# 2                      NaN                              NaN
# 3                      NaN                              NaN
# 4                      NaN                              NaN
# 5                      NaN                              NaN
# 6                      NaN                              NaN
# 7                      NaN                              NaN
# 8                      NaN                              NaN
# 9                      NaN                              NaN
# 10                     NaN                              NaN
# 11                     NaN                              NaN
# 12                     NaN                              NaN
# 13                     NaN                              NaN
# 14                     NaN                              NaN
# 15                     NaN                              NaN
# 16                     NaN                              NaN
# 17                     NaN                              NaN
# 18                     NaN                              NaN
# 19                     NaN                              NaN
# 20                     NaN                              NaN
# 21                     NaN                              NaN
# 22                     NaN                              NaN
# 23                     NaN                              NaN
# 24                     NaN                              NaN
# 25                     NaN                              NaN
# 26                0.647163                        -0.670983
# 27                     NaN                              NaN
# 28                     NaN                              NaN
# 29                     NaN                              NaN
# 30                     NaN                              NaN
# 31                     NaN                              NaN
# 32                     NaN                              NaN
# 33                     NaN                              NaN
# 34                     NaN                              NaN
# 35                     NaN                              NaN
# 36                     NaN                              NaN
# 37                     NaN                              NaN
# 38                     NaN                              NaN
#
#     c20_over_c3_dch_cap_at_c630_ah  var_q_c20_c574_c3_ah  \
# 0                              NaN                   NaN
# 1                              NaN                   NaN
# 2                              NaN                   NaN
# 3                              NaN                   NaN
# 4                              NaN                   NaN
# 5                              NaN                   NaN
# 6                              NaN                   NaN
# 7                              NaN                   NaN
# 8                              NaN                   NaN
# 9                              NaN                   NaN
# 10                             NaN                   NaN
# 11                             NaN                   NaN
# 12                             NaN                   NaN
# 13                             NaN                   NaN
# 14                             NaN                   NaN
# 15                             NaN                   NaN
# 16                             NaN                   NaN
# 17                             NaN                   NaN
# 18                             NaN                   NaN
# 19                             NaN                   NaN
# 20                             NaN                   NaN
# 21                             NaN                   NaN
# 22                             NaN                   NaN
# 23                             NaN                   NaN
# 24                             NaN                   NaN
# 25                             NaN                   NaN
# 26                        0.490965                   NaN
# 27                             NaN                   NaN
# 28                             NaN                   NaN
# 29                             NaN                   NaN
# 30                             NaN                   NaN
# 31                             NaN                   NaN
# 32                             NaN              0.051594
# 33                             NaN                   NaN
# 34                             NaN              0.145170
# 35                             NaN              0.141963
# 36                             NaN                   NaN
# 37                             NaN              0.107114
# 38                             NaN                   NaN
#
#                             var_q_c20_c574_c3_delta_q  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32  [-0.002519691951797293, -0.0014485186806658659...
# 33                                                NaN
# 34  [-0.0052402068448228565, -0.002185938488235601...
# 35  [-0.002653608365394972, 0.0001222671423641783,...
# 36                                                NaN
# 37  [-0.0034367907294874673, 7.946073040947157e-05...
# 38                                                NaN
#
#                           var_q_c20_c574_c3_voltage_v  c3_dch_cap_at_c573_ah  \
# 0                                                 NaN                    NaN
# 1                                                 NaN                    NaN
# 2                                                 NaN                    NaN
# 3                                                 NaN                    NaN
# 4                                                 NaN                    NaN
# 5                                                 NaN                    NaN
# 6                                                 NaN                    NaN
# 7                                                 NaN                    NaN
# 8                                                 NaN                    NaN
# 9                                                 NaN                    NaN
# 10                                                NaN                    NaN
# 11                                                NaN                    NaN
# 12                                                NaN                    NaN
# 13                                                NaN                    NaN
# 14                                                NaN                    NaN
# 15                                                NaN                    NaN
# 16                                                NaN                    NaN
# 17                                                NaN                    NaN
# 18                                                NaN                    NaN
# 19                                                NaN                    NaN
# 20                                                NaN                    NaN
# 21                                                NaN                    NaN
# 22                                                NaN                    NaN
# 23                                                NaN                    NaN
# 24                                                NaN                    NaN
# 25                                                NaN                    NaN
# 26                                                NaN                    NaN
# 27                                                NaN                    NaN
# 28                                                NaN                    NaN
# 29                                                NaN                    NaN
# 30                                                NaN                    NaN
# 31                                                NaN                    NaN
# 32  [4.2, 4.195180722891567, 4.190361445783132, 4....               1.859437
# 33                                                NaN                    NaN
# 34  [4.2, 4.195180722891567, 4.190361445783132, 4....               0.970881
# 35  [4.2, 4.195180722891567, 4.190361445783132, 4....               1.121599
# 36                                                NaN                    NaN
# 37  [4.2, 4.195180722891567, 4.190361445783132, 4....               0.971096
# 38                                                NaN                    NaN
#
#     c20_dch_cap_at_c574_ah  c20_minus_c3_dch_cap_at_c574_ah  \
# 0                      NaN                              NaN
# 1                      NaN                              NaN
# 2                      NaN                              NaN
# 3                      NaN                              NaN
# 4                      NaN                              NaN
# 5                      NaN                              NaN
# 6                      NaN                              NaN
# 7                      NaN                              NaN
# 8                      NaN                              NaN
# 9                      NaN                              NaN
# 10                     NaN                              NaN
# 11                     NaN                              NaN
# 12                     NaN                              NaN
# 13                     NaN                              NaN
# 14                     NaN                              NaN
# 15                     NaN                              NaN
# 16                     NaN                              NaN
# 17                     NaN                              NaN
# 18                     NaN                              NaN
# 19                     NaN                              NaN
# 20                     NaN                              NaN
# 21                     NaN                              NaN
# 22                     NaN                              NaN
# 23                     NaN                              NaN
# 24                     NaN                              NaN
# 25                     NaN                              NaN
# 26                     NaN                              NaN
# 27                     NaN                              NaN
# 28                     NaN                              NaN
# 29                     NaN                              NaN
# 30                     NaN                              NaN
# 31                     NaN                              NaN
# 32                1.906176                         0.046739
# 33                     NaN                              NaN
# 34                0.227044                        -0.743837
# 35                0.386324                        -0.735275
# 36                     NaN                              NaN
# 37                0.788292                        -0.182805
# 38                     NaN                              NaN
#
#     c20_over_c3_dch_cap_at_c574_ah
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
# 10                             NaN
# 11                             NaN
# 12                             NaN
# 13                             NaN
# 14                             NaN
# 15                             NaN
# 16                             NaN
# 17                             NaN
# 18                             NaN
# 19                             NaN
# 20                             NaN
# 21                             NaN
# 22                             NaN
# 23                             NaN
# 24                             NaN
# 25                             NaN
# 26                             NaN
# 27                             NaN
# 28                             NaN
# 29                             NaN
# 30                             NaN
# 31                             NaN
# 32                        1.025136
# 33                             NaN
# 34                        0.233854
# 35                        0.344440
# 36                             NaN
# 37                        0.811754
# 38                             NaN
#
# [39 rows x 684 columns]

# %%
df_corr_rt = df_corr[df_corr['is_room_temp_aging'] == True]
# df_corr_rt = df_corr_rt.drop(columns=['cellid', 'is_baseline_formation', 'is_room_temp_aging'])
df_corr_ht = df_corr[df_corr['is_room_temp_aging'] == False]
# df_corr_ht = df_corr_ht.drop(columns=['cellid', 'is_baseline_formation', 'is_room_temp_aging'])

# df_corr = df_corr.drop(columns=['cellid', 'is_baseline_formation', 'is_room_temp_aging'])

# %% [markdown]
# ## Flatten the table
# We want the columns to be:
# - Cycle Number
# - SOC for the DCR pulse
# - Measured DCR Value
# - Is Room Temperature
# - Is Fast Formation
# - Cell Number
# - Measured DCR
#
# Then we can use this table to make subplots

# %%
# Loop over each cell

results_dict_list = []

for index, row in df_corr.iterrows():
    
    dcr_variable_indices = np.where(['dcr_' in x for x in row.keys().values])

    dcr_variable_names = row.keys().values[dcr_variable_indices]

    for dcr_variable in dcr_variable_names:

        curr_dict = dict()

        curr_dict['cellid'] = row['cellid']
        curr_dict['is_room_temp_aging'] = row['is_room_temp_aging']
        curr_dict['is_baseline_formation'] = row['is_baseline_formation']
        curr_dict['retention_at_c400'] = row['retention_at_c400']
        curr_dict['dcr'] = row[dcr_variable]

        if 'initial' in dcr_variable:
            curr_dict['cycle_number'] = 'c0'
            curr_dict['soc'] = dcr_variable.split('_')[3]

        else:
            curr_dict['cycle_number'] = dcr_variable.split('_')[4]
            curr_dict['soc'] = dcr_variable.split('_')[1]

        results_dict_list.append(curr_dict)
        
df_flat = pd.DataFrame(results_dict_list)

# %%
df_flat
# Out:
#        cellid  is_room_temp_aging  is_baseline_formation  retention_at_c400  \
# 0           1                   0                      1           0.492051
# 1           1                   0                      1           0.492051
# 2           1                   0                      1           0.492051
# 3           1                   0                      1           0.492051
# 4           1                   0                      1           0.492051
# ...       ...                 ...                    ...                ...
# 19300      40                   0                      0           0.817960
# 19301      40                   0                      0           0.817960
# 19302      40                   0                      0           0.817960
# 19303      40                   0                      0           0.817960
# 19304      40                   0                      0           0.817960
#
#             dcr cycle_number  soc
# 0      0.056651           at  10s
# 1      0.036739           at   3s
# 2      0.028164           at   1s
# 3      0.048262           at  10s
# 4      0.032362           at   3s
# ...         ...          ...  ...
# 19300  0.029944           at   3s
# 19301  0.028235           at   1s
# 19302  0.034345           at  10s
# 19303  0.030081           at   3s
# 19304  0.028341           at   1s
#
# [19305 rows x 7 columns]

# %%
with sns.axes_style("white"):
    
    g = sns.FacetGrid(df_flat, 
                      row="soc", 
                      col="cycle_number", 
                      margin_titles=True, 
                      despine=True,
                      height=2.5)
g.map_dataframe(sns.scatterplot, "cellid", "dcr", hue="is_room_temp_aging", color="#334488")
g.set_titles(col_template="{col_name}", row_template="soc {row_name}")
g.fig.subplots_adjust(wspace=0, hspace=0)    
g.set_axis_labels("cell #", "DCR ($\Omega$)")
# g.set(xticks=[10, 30, 50], yticks=[2, 6, 10])

# %%
df_flat
# Out:
#        cellid  is_room_temp_aging  is_baseline_formation  retention_at_c400  \
# 0           1                   0                      1           0.492051
# 1           1                   0                      1           0.492051
# 2           1                   0                      1           0.492051
# 3           1                   0                      1           0.492051
# 4           1                   0                      1           0.492051
# ...       ...                 ...                    ...                ...
# 19300      40                   0                      0           0.817960
# 19301      40                   0                      0           0.817960
# 19302      40                   0                      0           0.817960
# 19303      40                   0                      0           0.817960
# 19304      40                   0                      0           0.817960
#
#             dcr cycle_number  soc
# 0      0.056651           at  10s
# 1      0.036739           at   3s
# 2      0.028164           at   1s
# 3      0.048262           at  10s
# 4      0.032362           at   3s
# ...         ...          ...  ...
# 19300  0.029944           at   3s
# 19301  0.028235           at   1s
# 19302  0.034345           at  10s
# 19303  0.030081           at   3s
# 19304  0.028341           at   1s
#
# [19305 rows x 7 columns]
